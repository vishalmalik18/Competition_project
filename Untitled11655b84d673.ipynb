# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalmalik18/Competition_project/blob/main/Untitled11655b84d673.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import datasets
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Dropout,Flatten
from tensorflow.keras.layers import Conv2D,MaxPooling2D
from sklearn.metrics import classification_report,confusion_matrix

# %%
(x_train,y_train),(x_test,y_test) = datasets.cifar10.load_data()

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
plt.figure(figsize=(15,2))
plt.imshow(x_train[1])

# %%
y_train = y_train.reshape(-1,)

# %%
x_train = x_train/255
x_test = x_test/255

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
model = Sequential()

model.add(Conv2D(filters=32,kernel_size=(3,3),activation='relu',input_shape=(32,32,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dense(10,activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2304)           │             0 │
# ...

# %%
model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.3950 - loss: 1.6685
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6111 - loss: 1.1093
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6677 - loss: 0.9551
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7042 - loss: 0.8579
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7314 - loss: 0.7776
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7528 - loss: 0.7142
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7719 - loss: 0.6555
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7900 - loss: 0.6068
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8090 - loss: 0.5473
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8223 - loss: 0.5066

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6965 - loss: 0.9786
# [0.9793859124183655, 0.6958000063896179]

# %%
y_pred = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
y_pred
# Out:
# array([[1.3855373e-05, 1.2568333e-06, 7.1429349e-05, ..., 8.4806328e-05,
#         1.6815445e-03, 9.1262550e-08],
#        [3.2902211e-02, 6.1344683e-02, 6.8005952e-09, ..., 3.9575392e-09,
#         9.0573287e-01, 2.0217187e-05],
#        [4.5370325e-02, 4.3208189e-03, 1.6858999e-04, ..., 1.0734152e-04,
#         9.4281906e-01, 7.0028747e-03],
#        ...,
#        [1.8701183e-04, 1.8995654e-07, 5.9216965e-02, ..., 4.1150770e-01,
#         1.0975048e-07, 3.7330591e-07],
#        [2.0655009e-01, 6.0632360e-01, 1.0547312e-03, ..., 2.8483868e-03,
#         1.0675156e-04, 1.9293011e-04],
#        [5.2219338e-08, 3.1294260e-08, 9.8948010e-07, ..., 9.9983382e-01,
#         1.0682368e-11, 1.0034062e-08]], dtype=float32)

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
y_classes = [np.argmax(element) for element in y_pred]
y_classes[:5]
# Out:
# [np.int64(3), np.int64(8), np.int64(8), np.int64(0), np.int64(4)]

# %%
y_classes
# Out:
# [np.int64(3),
#  np.int64(8),
#  np.int64(8),
#  np.int64(0),
#  np.int64(4),
#  np.int64(6),
#  np.int64(9),
#  np.int64(2),
#  np.int64(3),
#  np.int64(1),
#  np.int64(0),
#  np.int64(9),
#  np.int64(5),
#  np.int64(7),
#  np.int64(9),
#  np.int64(8),
#  np.int64(5),
#  np.int64(9),
#  np.int64(8),
#  np.int64(6),
#  np.int64(7),
#  np.int64(0),
#  np.int64(4),
#  np.int64(9),
#  np.int64(4),
#  np.int64(2),
#  np.int64(7),
#  np.int64(0),
#  np.int64(9),
#  np.int64(6),
#  np.int64(6),
#  np.int64(5),
#  np.int64(4),
#  np.int64(3),
#  np.int64(9),
#  np.int64(1),
#  np.int64(7),
#  np.int64(1),
#  np.int64(9),
#  np.int64(5),
#  np.int64(0),
#  np.int64(6),
#  np.int64(7),
#  np.int64(6),
#  np.int64(0),
#  np.int64(9),
#  np.int64(3),
#  np.int64(4),
#  np.int64(7),
#  np.int64(4),
#  np.int64(9),
#  np.int64(0),
#  np.int64(6),
#  np.int64(3),
#  np.int64(8),
#  np.int64(8),
#  np.int64(3),
#  np.int64(7),
#  np.int64(2),
#  np.int64(5),
#  np.int64(7),
#  np.int64(5),
# ...

# %%
y_test = y_test.reshape(-1,)

# %%
print(classification_report(y_test,y_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.84      0.73      1000
#            1       0.81      0.83      0.82      1000
#            2       0.64      0.56      0.60      1000
#            3       0.53      0.48      0.50      1000
#            4       0.68      0.62      0.64      1000
#            5       0.61      0.61      0.61      1000
#            6       0.82      0.72      0.77      1000
#            7       0.61      0.84      0.71      1000
#            8       0.85      0.75      0.79      1000
#            9       0.86      0.71      0.78      1000
#
#     accuracy                           0.70     10000
#    macro avg       0.70      0.70      0.69     10000
# weighted avg       0.70      0.70      0.69     10000
